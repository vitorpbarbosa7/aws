# %%
import requests

# %%
x = requests.get('https://w3schools.com/python/demopage.htm')

print(x.text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>This is a Test Page</h1>
#
# </body>
# </html>

# %%
a = requests.get('https://www.facebook.com')

# %%
from IPython.display import display
from IPython.core.display import HTML

# %%
#static
display(HTML(a.text))
# Out:
# <!DOCTYPE html>
# <html lang="pt" id="facebook" class="no_js">
# <head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script nonce="wjSlYkwc">function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"hostnameRewriterConfig":{"site":"internet.org","inboundName":"web.facebook.com","cdnDomainName":null},"ajaxpipe_token":"AXgGw9eWL2PLEJ9luE4","gk_instrument_object_url":true,"gk_log_promise_done":true,"stack_trace_limit":30,"timesliceBufferSize":5000,"show_invariant_decoder":false,"compat_iframe_token":"AQ7aMtj5ClObd2-9qPs","isCQuick":false});</script><script nonce="wjSlYkwc">(function(a){function b(b){if(!window.openDatabase)return;b.I_AM_INCOGNITO_AND_I_REALLY_NEED_WEBSQL=function(a,b,c,d){return window.openDatabase(a,b,c,d)};window.openDatabase=function(){throw new Error()}}b(a)})(this);</script><style nonce="wjSlYkwc"></style><script nonce="wjSlYkwc">__DEV__=0;CavalryLogger=false;</script><noscript><meta http-equiv="refresh" content="0; URL=/?_rdc=1&amp;_rdr&amp;_fb_noscript=1" /></noscript><link rel="manifest" id="MANIFEST_LINK" href="/data/manifest/" crossorigin="use-credentials" /><title id="pageTitle">Facebook – entre ou cadastre-se</title><meta property="og:site_name" content="Facebook" /><meta property="og:url" content="https://web.facebook.com/" /><meta property="og:image" content="https://www.facebook.com/images/fb_icon_325x325.png" /><meta property="og:locale" content="pt_BR" /><meta property="og:locale:alternate" content="www" /><meta property="og:locale:alternate" content="es_LA" /><meta property="og:locale:alternate" content="es_ES" /><meta property="og:locale:alternate" content="fr_FR" /><meta property="og:locale:alternate" content="it_IT" /><meta property="og:locale:alternate" content="id_ID" /><meta property="og:locale:alternate" content="th_TH" /><meta property="og:locale:alternate" content="vi_VN" /><meta property="og:locale:alternate" content="ko_KR" /><meta property="og:locale:alternate" content="ja_JP" /><link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.facebook.com/" /><link rel="alternate" media="handheld" href="https://m.facebook.com/" /><meta name="description" content="Entre no Facebook para come&#xe7;ar a compartilhar e se conectar com seus amigos, familiares e com as pessoas que voc&#xea; conhece." /><link rel="canonical" href="https://web.facebook.com/" /><link rel="shortcut icon" href="https://static.xx.fbcdn.net/rsrc.php/yv/r/B8BxsscfVBr.ico" /><link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yU/l/0,cross/JM4Vvftiu_N.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="EEHBV35" />
# <link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yk/l/0,cross/jctzZ86UoIU.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="TNuaAeq" />
# <link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yA/l/0,cross/s65aZkU52Mg.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="NsZYKoo" />
# <link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yz/l/0,cross/M9LajOiBjPW.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="kY83Ck6" />
# <link type="text/css" rel="stylesheet" href="https://static.xx.fbcdn.net/rsrc.php/v3/yr/l/0,cross/u4xvA0Tw-4L.css?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="Yo2UzOh" />
# <script src="https://static.xx.fbcdn.net/rsrc.php/v3/yL/r/EJYXkb1ltf3.js?_nc_x=Ij3Wp8lg5Kz" data-bootloader-hash="WcTwUjU" nonce="wjSlYkwc"></script>
# <script nonce="wjSlYkwc">requireLazy(["HasteSupportData"],function(m){m.handle({"clpData":{"1814852":{"r":1},"1838142":{"r":1,"s":1},"1949898":{"r":1},"1848815":{"r":10000,"s":1},"1744178":{"r":1,"s":1}},"gkxData":{"5241":{"result":true,"hash":"AT7o1bCQPGpf3ShE9ls"},"5919":{"result":false,"hash":"AT6PGptIPUYH051B6is"},"676837":{"result":false,"hash":"AT4N8wBZA8ctCdHw2GY"},"708253":{"result":false,"hash":"AT5n4hBL3YTMnQWty84"},"996940":{"result":false,"hash":"AT7opYuEGy3sjG1aDHU"},"1224637":{"result":false,"hash":"AT7JRluWxuwDm3XzXhM"},"1263340":{"result":false,"hash":"AT5bwizWgDaFQudm1Jw"},"676920":{"result":true,"hash":"AT497IX4gOFG8gZe5Dc"},"1073500":{"result":false,"hash":"AT7aJmfnqWyioxOOG8M"},"1167394":{"result":false,"hash":"AT7BpN-tlUPwbIIFHsM"},"1857581":{"result":false,"hash":"AT5yTxGMp6le0PAtvxs"},"2772":{"result":false,"hash":"AT5Eu244WIce7iwqCq0"},"3752":{"result":false,"hash":"AT6eS5UTkkMp_xbPhog"},"3831":{"result":false,"hash":"AT4W23lQ0XxAZniMBh4"},"4075":{"result":false,"hash":"AT4_ZQi0sTjSt-RxpyA"},"676838":{"result":false,"hash":"AT6nN1ehT9yq-2q6f0A"},"1217157":{"result":false,"hash":"AT6B7YmllOsArnK6oFc"},"1554827":{"result":false,"hash":"AT7zueGLhGo0cT5xgIY"},"1738486":{"result":false,"hash":"AT4cX37oQco6DwhU4xY"}},"qplData":{"7758":{"r":1}}})});requireLazy(["TimeSliceImpl","ServerJS"],function(TimeSlice,ServerJS){(new ServerJS()).handle({"define":[["URLFragmentPreludeConfig",[],{"hashtagRedirect":true,"fragBlacklist":["nonce","access_token","oauth_token","xs","checkpoint_data","code"]},137],["CometPersistQueryParams",[],{"relative":{},"domain":{}},6231],["CookieDomain",[],{"domain":"facebook.com"},6421],["BootloaderConfig",[],{"deferBootloads":false,"jsRetries":[200,500],"jsRetryAbortNum":2,"jsRetryAbortTime":5,"silentDups":false,"hypStep4":false,"phdOn":false,"btCutoffIndex":2574,"translationRetries":[200,500],"translationRetryAbortNum":3,"translationRetryAbortTime":50},329],["CSSLoaderConfig",[],{"timeout":5000,"modulePrefix":"BLCSS:"},619],["CookieCoreConfig",[],{"c_user":{},"cppo":{"t":86400},"dpr":{"t":604800},"fbl_ci":{"t":31536000},"fbl_cs":{"t":31536000},"fbl_st":{"t":31536000},"i_user":{},"locale":{"t":604800},"m_ls":{"t":158284800},"m_pixel_ratio":{"t":604800},"noscript":{},"presence":{"t":2592000},"sfau":{},"usida":{},"vpd":{"t":5184000},"wd":{"t":604800},"x-referer":{},"x-src":{"t":1}},2104],["CurrentCommunityInitialData",[],{},490],["CurrentEnvironment",[],{"facebookdotcom":true,"messengerdotcom":false,"workplacedotcom":false,"instagramdotcom":false},827],["CurrentUserInitialData",[],{"ACCOUNT_ID":"0","USER_ID":"0","NAME":"","SHORT_NAME":null,"IS_BUSINESS_PERSON_ACCOUNT":false,"HAS_SECONDARY_BUSINESS_PERSON":false,"IS_FACEBOOK_WORK_ACCOUNT":false,"IS_MESSENGER_ONLY_USER":false,"IS_DEACTIVATED_ALLOWED_ON_MESSENGER":false,"IS_MESSENGER_CALL_GUEST_USER":false,"IS_WORK_MESSENGER_CALL_GUEST_USER":false,"IS_WORKROOMS_USER":false,"APP_ID":"256281040558","IS_BUSINESS_DOMAIN":false},270],["DTSGInitialData",[],{},258],["ISB",[],{},330],["LSD",[],{"token":"AVpX0_ynsK4"},323],["ServerNonce",[],{"ServerNonce":"LFSw0VwLsDHLFbLcxjjzpl"},141],["SiteData",[],{"server_revision":1006042628,"client_revision":1006042628,"tier":"","push_phase":"C3","pkg_cohort":"BP:DEFAULT","haste_session":"19221.BP:DEFAULT.2.0.0.0.0","pr":1,"haste_site":"www","manifest_base_uri":"https:\/\/static.xx.fbcdn.net","manifest_origin":null,"be_one_ahead":false,"is_rtl":false,"is_comet":false,"is_experimental_tier":false,"is_jit_warmed_up":true,"hsi":"7132915015673859719","semr_host_bucket":"5","bl_hash_version":2,"skip_rd_bl":true,"comet_env":0,"wbloks_env":false,"spin":4,"__spin_r":1006042628,"__spin_b":"trunk","__spin_t":1660761194,"vip":"2a03:2880:f005:20c:face:b00c:0:2"},317],["SprinkleConfig",[],{"param_name":"jazoest","version":2,"should_randomize":false},2111],["UserAgentData",[],{"browserArchitecture":"32","browserFullVersion":null,"browserMinorVersion":null,"browserName":"Unknown","browserVersion":null,"deviceName":"Unknown","en ...
